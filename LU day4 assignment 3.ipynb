# %%
# file handling

# %%
xyz=open("Sridhar.txt",'w')
xyz.write("I love LetsUpgrade")
xyz.close()

# %%
xyz=open("Sridhar.txt",'r')
Data=xyz.read()
xyz.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-99ace6f3d74e> in <module>()
# ----> 1 xyz=open("Sridhar.txt",'r')
#       2 Data=xyz.read()
#       3 xyz.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Sridhar.txt'

# %%
Data
# Out:
# 'I love LetsUpgrade'

# %%
xyz=open("Sridhar.txt",'a')
xyz.write(" and it is a great learning platform")
xyz.close()

# %%
xyz=open("Sridhar.txt",'r')
Data=xyz.read()
xyz.close()

# %%
Data
# Out:
# 'I love LetsUpgrade and it is a great learning platform'

# %%
#factorial of a given number

# %%
def fact(num):
  if num==1:
    return 1
  A=num*fact(num-1)
  return A

# %%
fact(5)
# Out:
# 120

# %%
fact(8)
# Out:
# 40320
